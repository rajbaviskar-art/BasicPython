# %% [markdown]
# <a href="https://colab.research.google.com/github/rajbaviskar-art/BasicPython/blob/main/8_Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Modules
#
# Consider a module to be the same as a code library. It's a file containing a set of functions you want ot include.

# %% [markdown]
# Below is another py file I created for module named my_module

# %%
skill_list = ['Python', 'SQL','Excel']

def skill(skill_name):
  return f'{skill_name} is my favourite skill'

# %%
import my_module

# %%
my_module.skill_list
# Out:
# ['Python', 'SQL', 'Excel']

# %%
my_module.skill("Python")
# Out:
# 'Python is my favourite skill'

# %% [markdown]
# The below is a py file for module I created named job_analyzer

# %%
def calculate_salary(base_salary, bonus_rate = 0.1):
  """
  Calculate the total salary base on the base salary and bonus rate

  Args:
    base_salary (float): The base salary.
    bonus_rate (float): The bonus rate. Default is 0.1.

  Returns:
    float: The total salary.
  """
  return base_salary * (1 + bonus_rate)

def calculate_bonus(total_salary, base_salary):
  """
  Calculates the bonus rate from total_salary and base_salary

  Args:
    total_salary (float): The tota salary.
    base_salary (float): The base salary.

  Returns:
    float: The bonus rate.
  """

  return (total_salary - base_salary) / base_salary

# %%
import job_analyzer

job_analyzer.calculate_salary(100000)
# Out:
# 110000.00000000001

# %%
from job_analyzer import calculate_salary

calculate_salary(100000)
# Out:
# 110000.00000000001

# %%
from job_analyzer import calculate_salary, calculate_bonus

print(calculate_bonus(11000, 10000))
calculate_salary(100000)
# Out:
# 0.1
# 110000.00000000001

# %%
from job_analyzer import *
calculate_salary(10000)
calculate_bonus(11000,10000)
# Out:
# 0.1

# %%
import job_analyzer

job_analyzer.calculate_bonus(11000,10000)
# Out:
# 0.1

# %%
help(calculate_salary)
# Out:
# Help on function calculate_salary in module job_analyzer:
#
# calculate_salary(base_salary, bonus_rate=0.1)
#     Calculate the total salary base on the base salary and bonus rate
#
#     Args:
#       base_salary (float): The base salary.
#       bonus_rate (float): The bonus rate. Default is 0.1.
#
#     Returns:
#       float: The total salary.

# %% [markdown]
# ##Python Standard Library

# %% [markdown]
# ###Statistics Module

# %%
salary_list = [980000, 875000, 1400000, 2000000]

# %%
import statistics

statistics.mean(salary_list)
# Out:
# 1313750

# %%
from statistics import mean, median, mode

mean(salary_list)
# Out:
# 1313750

# %%
mode(salary_list)
# Out:
# 980000

# %%
median(salary_list)
# Out:
# 1190000.0

# %% [markdown]
# #Exercise on Data Cleaning

# %% [markdown]
# Cleanup `list` and `datetime` objects

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %% [markdown]
# **DateTime**

# %%
from datetime import datetime, date

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 5, 8, 7, 35, 5, 945822)

# %%
type(data_science_jobs[0]['job_date'])
# Out:
# str

# %%
test_date = data_science_jobs[0]['job_date']

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')

data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': "['Python', 'SQL', 'Machine Learning']",
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': "['Python', 'TensorFlow', 'Deep Learning']",
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['SQL', 'R', 'Tableau']",
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']",
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': "['Python', 'Spark', 'Hadoop']",
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': "['Python', 'PyTorch', 'AI Ethics']",
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)}]

# %% [markdown]
# **AST Abstract Syntax Trees**

# %%
import ast

for job in data_science_jobs:
  job['job_skills'] = ast.literal_eval(job['job_skills'])

data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['SQL', 'R', 'Tableau'],
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': ['SQL', 'PowerBI', 'Data Warehousing'],
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'Hadoop'],
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': ['Python', 'PyTorch', 'AI Ethics'],
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)}]
