# %% [markdown]
# <a href="https://colab.research.google.com/github/rajbaviskar-art/BasicPython/blob/main/13_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Matplotlib
#
# - Matplotlib is a library for creating static, interactive, and animated visualizations in Python.
# - Some of the major plot types available in Matplotlib are line, bar, scatter, histogram, and pie charts, along with many others.
# - It's highly customizable and can be used to create complex plots by layering elements.

# %%
# Importing a specific module from matplotlib

from matplotlib import pyplot as plt
import numpy as np

# %%
#Testing a plot as sample plot
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# ##Plotting

# %% [markdown]
# ###Line chart

# %%
# Simple ecample
x = [1 ,2, 3, 4]
y = [1, 2, 3, 4]
plt.plot(x, y)
plt.show()

# %% [markdown]
# ####Plotting Job Posting Dates

# %%
# Installing and importing necessary libraries

# !pip install datasets
import pandas as pd
from datasets import load_dataset
from matplotlib import pyplot as plt

# %%
#Loading the datasets

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# ...

# %%
#Cleaning the job_posted_date as it is str instead of datetime

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.head()
# Out:
# 0   2023-06-16 13:44:15
# 1   2023-01-14 13:18:07
# 2   2023-10-10 13:14:55
# 3   2023-07-04 13:01:41
# 4   2023-08-07 14:29:36
# Name: job_posted_date, dtype: datetime64[ns]

# %%
# Count of job posted per day
date_counts = df.job_posted_date.value_counts()
date_counts = date_counts.sort_index()

# %%
plt.plot(date_counts.index, date_counts)

# %%
# Instead of plotting directly over dates we would plot it over months
df['job_posted_month'] = df['job_posted_date'].dt.month
monthly_counts = df.job_posted_month.value_counts()
monthly_counts = monthly_counts.sort_index()
monthly_counts
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
plt.plot(monthly_counts.index, monthly_counts.values)

# %% [markdown]
# ### Bar Char - Counts of Job Postings

# %%
job_counts = df.job_title_short.value_counts()

# %%
job_counts
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
plt.bar(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.barh(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts = job_counts.sort_values(ascending = True)
plt.barh(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Labeling

# %%
job_counts = job_counts.sort_values(ascending = False)
plt.bar(job_counts.index, job_counts)
plt.title('Postings by Job Title')
plt.ylabel('Count of Job POstings')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel('Job Title')
# Out:
# Text(0.5, 0, 'Job Title')

# %% [markdown]
# # Series Vs Dataframe
# - One-Dimensional
# - Indexed
# - Diverse Data Types
#
# A column of data within a dataframe is also a series

# %%
series = pd.Series([10, 20, 30, 40, 50], index = ['a', 'b', 'c', 'd', 'e'])

# %%
series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
series.values
# Out:
# array([10, 20, 30, 40, 50])

# %% [markdown]
# ##Exercise

# %%
#Importing and installing necessary libraries
# !pip install datasets

import pandas as pd
from datasets import load_dataset
from matplotlib import pyplot as plt

# Loading dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Cleaning data
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
job_salary  = df.groupby('job_title_short')['salary_year_avg'].median().sort_values()

# %%
job_salary.plot(kind = 'barh')
plt.xlabel('Salary ($USD)')
plt.ylabel('Job Title')
plt.title('Median Salary by Job Title')
# Out:
# Text(0.5, 1.0, 'Median Salary by Job Title')
